# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Car = pd.read_csv("Automobile_data.csv", index_col=0)
Car
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
Car.company.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mitsubishi',
#        'nissan', 'porsche', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
print(Car.head())
print(Car.shape)
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0            1           1        88.6   168.8            1                 4
# 1            1           1        88.6   168.8            1                 4
# 2            1           2        94.5   171.2            2                 6
# 3            2           3        99.8   176.6            3                 4
# 4            2           3        99.4   176.6            3                 5
#
#        horsepower  average-mileage    price
# index
# 0             111               21  13495.0
# 1             111               21  16500.0
# 2             154               19  16500.0
# 3             102               24  13950.0
# 4             115               18  17450.0
# (61, 9)

# %%
Car['engine-type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
Car['body-style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
Car['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
Car=Car.replace({"company":{"alfa-romero": 1, "audi": 2, "bmw": 3, "chevrolet": 4, "dodge": 5, "honda": 6, 
                        "isuzu": 7, "jaguar": 8, "mazda": 9, "mercedes-benz": 10, "mitsubishi": 11, "nissan": 12, 
                        "porsche": 13, "toyota": 14, "volkswagen": 15, "volvo": 16 },
            "body-style":{"convertible":1, "hatchback":2, "sedan":3, "wagon":4, "hardtop":5},
            "engine-type":{"dohc":1, "ohcv":2, "ohc":3, "rotor":4, "ohcf":5, "l":6, "dohcv":7},
            "num-of-cylinders":{"two":2, "three":3, "four":4, "five":5, "six":6, "eight":8, "twelve": 12}})
Car
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0            1           1        88.6   168.8            1                 4
# 1            1           1        88.6   168.8            1                 4
# 2            1           2        94.5   171.2            2                 6
# 3            2           3        99.8   176.6            3                 4
# 4            2           3        99.4   176.6            3                 5
# ...        ...         ...         ...     ...          ...               ...
# 81          15           3        97.3   171.7            3                 4
# 82          15           3        97.3   171.7            3                 4
# 86          15           3        97.3   171.7            3                 4
# 87          16           3       104.3   188.8            3                 4
# 88          16           4       104.3   188.8            3                 4
#
# ...

# %%
sns.pairplot(Car[['horsepower','average-mileage','price','wheel-base','num-of-cylinders']])

# %%
Car.corr()
# Out:
#                    company  body-style  wheel-base    length  engine-type  \
# company           1.000000    0.238017   -0.005248 -0.027407     0.168310
# body-style        0.238017    1.000000    0.436064  0.434224    -0.067495
# wheel-base       -0.005248    0.436064    1.000000  0.878381    -0.346820
# length           -0.027407    0.434224    0.878381  1.000000    -0.376854
# engine-type       0.168310   -0.067495   -0.346820 -0.376854     1.000000
# num-of-cylinders -0.052472    0.194506    0.499083  0.614195    -0.121902
# horsepower       -0.104871    0.109607    0.463421  0.668555     0.047965
# average-mileage   0.193498   -0.187963   -0.547325 -0.788429     0.228543
# price            -0.205502    0.264650    0.663085  0.788465    -0.184410
#
#                   num-of-cylinders  horsepower  average-mileage     price
# company                  -0.052472   -0.104871         0.193498 -0.205502
# body-style                0.194506    0.109607        -0.187963  0.264650
# ...

# %%
plt.figure(figsize=(7,5))
sns.set_style('whitegrid')
sns.heatmap(data=Car.corr(),
           annot=True,
           linewidth=0.5,
           cmap="GnBu")
plt.suptitle("Correlation Matrix of Cars")
plt.show()

# %%
Car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     int64
#  1   body-style        61 non-null     int64
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     int64
#  5   num-of-cylinders  61 non-null     int64
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             58 non-null     float64
# dtypes: float64(3), int64(6)
# memory usage: 6.8 KB

# %%
Car.describe()
# Out:
#          company  body-style  wheel-base      length  engine-type  \
# count  61.000000   61.000000   61.000000   61.000000    61.000000
# mean    8.721311    2.868852   98.481967  173.098361     2.950820
# std     4.615666    0.846077    6.679234   14.021846     0.990391
# min     1.000000    1.000000   88.400000  141.100000     1.000000
# 25%     4.000000    2.000000   94.500000  159.100000     3.000000
# 50%     9.000000    3.000000   96.300000  171.200000     3.000000
# 75%    13.000000    3.000000  101.200000  177.300000     3.000000
# max    16.000000    5.000000  120.900000  208.100000     7.000000
#
#        num-of-cylinders  horsepower  average-mileage         price
# count         61.000000   61.000000        61.000000     58.000000
# mean           4.721311  107.852459        25.803279  15387.000000
# std            1.495896   53.524398         8.129821  11320.259841
# min            2.000000   48.000000        13.000000   5151.000000
# ...

# %%
Car.isna().sum().to_frame()
# Out:
#                   0
# company           0
# body-style        0
# wheel-base        0
# length            0
# engine-type       0
# num-of-cylinders  0
# horsepower        0
# average-mileage   0
# price             3

# %%
Car.fillna(method='ffill',inplace=True)

# %%
Car.isna().sum().to_frame()
# Out:
#                   0
# company           0
# body-style        0
# wheel-base        0
# length            0
# engine-type       0
# num-of-cylinders  0
# horsepower        0
# average-mileage   0
# price             0

# %%
Car.describe()
# Out:
#          company  body-style  wheel-base      length  engine-type  \
# count  61.000000   61.000000   61.000000   61.000000    61.000000
# mean    8.721311    2.868852   98.481967  173.098361     2.950820
# std     4.615666    0.846077    6.679234   14.021846     0.990391
# min     1.000000    1.000000   88.400000  141.100000     1.000000
# 25%     4.000000    2.000000   94.500000  159.100000     3.000000
# 50%     9.000000    3.000000   96.300000  171.200000     3.000000
# 75%    13.000000    3.000000  101.200000  177.300000     3.000000
# max    16.000000    5.000000  120.900000  208.100000     7.000000
#
#        num-of-cylinders  horsepower  average-mileage         price
# count         61.000000   61.000000        61.000000     61.000000
# mean           4.721311  107.852459        25.803279  15459.737705
# std            1.495896   53.524398         8.129821  11489.452464
# min            2.000000   48.000000        13.000000   5151.000000
# ...

# %%
Car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     int64
#  1   body-style        61 non-null     int64
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     int64
#  5   num-of-cylinders  61 non-null     int64
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             61 non-null     float64
# dtypes: float64(3), int64(6)
# memory usage: 6.8 KB

# %%
plt.style.use('ggplot')
Car[['company', 
         'body-style', 
         'wheel-base', 
         'length',
         'horsepower', 
         'average-mileage']].hist(bins=30,
                         figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.style.use("ggplot")

sns.countplot(x="horsepower", data=Car)
plt.title('horsepower')
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.style.use("ggplot")

sns.countplot(x="length", data=Car)
plt.title('length')
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.style.use("ggplot")

sns.countplot(x="num-of-cylinders", data=Car)
plt.title('num-of-cylinders')
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.style.use("ggplot")

sns.barplot(x="horsepower", y="price", data=Car)
plt.title(' rges')
plt.show()

# %%
Car
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0            1           1        88.6   168.8            1                 4
# 1            1           1        88.6   168.8            1                 4
# 2            1           2        94.5   171.2            2                 6
# 3            2           3        99.8   176.6            3                 4
# 4            2           3        99.4   176.6            3                 5
# ...        ...         ...         ...     ...          ...               ...
# 81          15           3        97.3   171.7            3                 4
# 82          15           3        97.3   171.7            3                 4
# 86          15           3        97.3   171.7            3                 4
# 87          16           3       104.3   188.8            3                 4
# 88          16           4       104.3   188.8            3                 4
#
# ...

# %%
y=Car.iloc[:,8]

# %%
x=Car.iloc[:,0:8]

# %%
y
# Out:
# index
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 81     7975.0
# 82     7995.0
# 86     9995.0
# 87    12940.0
# 88    13415.0
# Name: price, Length: 61, dtype: float64

# %%
x
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0            1           1        88.6   168.8            1                 4
# 1            1           1        88.6   168.8            1                 4
# 2            1           2        94.5   171.2            2                 6
# 3            2           3        99.8   176.6            3                 4
# 4            2           3        99.4   176.6            3                 5
# ...        ...         ...         ...     ...          ...               ...
# 81          15           3        97.3   171.7            3                 4
# 82          15           3        97.3   171.7            3                 4
# 86          15           3        97.3   171.7            3                 4
# 87          16           3       104.3   188.8            3                 4
# 88          16           4       104.3   188.8            3                 4
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,
                                                   y,
                                                   test_size=0.20,
                                                   random_state=0)

# %%
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (48, 8)
# x_test shape: (13, 8)
# y_train shape: (48,)
# y_test shape: (13,)

# %%
x_train
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 54          12           3        94.5   165.3            3                 4
# 45          10           4       110.0   190.9            3                 5
# 56          12           4        94.5   170.2            3                 4
# 67          14           2        95.7   158.7            3                 4
# 9            3           3       101.2   176.8            3                 4
# 17           4           2        94.5   155.9            3                 4
# 44          10           3       110.0   190.9            3                 5
# 69          14           4        95.7   169.7            3                 4
# 38           9           2        93.1   159.1            3                 4
# 55          12           3        94.5   165.3            3                 4
# 80          15           3        97.3   171.7            3                 4
# ...

# %%
x_test
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 35           8           3       102.0   191.7            2                12
# 47          10           5       112.0   199.2            2                 8
# 88          16           4       104.3   188.8            3                 4
# 37           9           2        93.1   159.1            3                 4
# 14           3           3       103.5   193.8            3                 6
# 2            1           2        94.5   171.2            2                 6
# 46          10           3       120.9   208.1            2                 8
# 87          16           3       104.3   188.8            3                 4
# 53          12           3        94.5   165.3            3                 4
# 31           7           3        94.5   155.9            3                 4
# 4            2           3        99.4   176.6            3                 5
# ...

# %%
y_test
# Out:
# index
# 35    36000.0
# 47    45400.0
# 88    13415.0
# 37     6095.0
# 14    41315.0
# 2     16500.0
# 46    40960.0
# 87    12940.0
# 53     7099.0
# 31     6785.0
# 4     17450.0
# 13    30760.0
# 39    11845.0
# Name: price, dtype: float64

# %%
y_train
# Out:
# index
# 54     6649.0
# 45    28248.0
# 56     7349.0
# 67     6338.0
# 9     16430.0
# 17     6295.0
# 44    25552.0
# 69     6918.0
# 38     6795.0
# 55     6849.0
# 80     7775.0
# 27     7295.0
# 82     7995.0
# 36     5195.0
# 18     6575.0
# 5     15250.0
# 43    18344.0
# 19     6377.0
# 70     7898.0
# 29    10345.0
# 86     9995.0
# 10    16925.0
# 16     5151.0
# 34    35550.0
# 50     6189.0
# 20     6229.0
# 61    34028.0
# 66     5348.0
# 79    15750.0
# 51     6989.0
# 1     16500.0
# 15    36880.0
# 62    37028.0
# 33    32250.0
# 6     18920.0
# 32     6785.0
# 49     5389.0
# 68     6488.0
# 30     6785.0
# 28    12945.0
# 11    20970.0
# 52     8189.0
# 81     7975.0
# 3     13950.0
# 0     13495.0
# 71     8778.0
# 63    37028.0
# 57    13499.0
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

Car_Price = LinearRegression()
Car_Price.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
m=Car_Price.coef_
c=Car_Price.intercept_
m,c
# Out:
# (array([ -134.20217942,  -660.93985914,   313.28770794,   192.85372656,
#          1288.30931853, -1779.4076578 ,   167.71218493,    34.08542184]),
#  -60356.45156257014)

# %%
c
# Out:
# -60356.45156257014

# %%
y_pred_train = Car_Price.predict(x_train)
y_pred_train
# Out:
# array([ 6910.79826822, 23281.55917249,  7194.84166921,  5232.45912828,
#        17529.56992456,  7238.84067089, 23942.49903163,  6031.97040213,
#         6172.33658494,  6910.79826822,  5973.06654942,  7240.14621636,
#         5973.06654942,  6138.2511631 ,  7137.17661877, 16915.25649533,
#        12945.41467143,  6549.98121959,  5895.62871478, 14069.99612323,
#        13648.31178565, 17529.56992456,  4734.98684099, 31122.71548868,
#         5744.76814305,  6549.98121959, 26267.44018191,  5368.80081563,
#        21500.04105097, 11960.19876306, 12661.93143773, 33935.33531955,
#        28911.19961849, 31122.71548868, 21103.9902728 ,  6175.29427348,
#         5949.28067407,  5232.45912828,  9831.37345864, 15418.60136363,
#        17256.82746379, 11960.19876306, 11166.71443361, 17388.39617432,
#        12661.93143773,  5895.62871478, 44952.41600102, 21145.23432026])

# %%
y_pred_test = Car_Price.predict(x_test)
y_pred_test
# Out:
# array([31119.9466932 , 28179.10827348, 20589.69675024,  6172.33658494,
#        31315.91871481, 19185.18511021, 34005.64675878, 21250.63660938,
#         5040.02358497,  6175.29427348, 17459.41930635, 30390.22082733,
#        18675.2522663 ])

# %%
from sklearn.metrics import mean_absolute_error,r2_score

# %%
mean_absolute_error(y_test,y_predict_test)
# Out:
# 5167.720577029375

# %%
mean_absolute_error(y_train,y_predict_train)
# Out:
# 2458.032407198801

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mean_squared_error(y_test,y_predict_test)
# Out:
# 49836779.87321127

# %%
mean_squared_error(y_train,y_predict_train)
# Out:
# 11151693.608552448

# %%
accuracy=r2_score(y_test,y_predict_test)

# %%
accuracy
# Out:
# 0.74782799398451

# %%
print("accuracy is",accuracy*100)
# Out:
# accuracy is 74.782799398451

# %%
r2score_train= r2_score(y_train, y_pred_train)
r2score_train
# Out:
# 0.8845175406287813

# %%
plt.style.use("default")

plt.figure(figsize=(4, 4))
sns.regplot(x=y_test, y=y_pred_test, ci=None, color="red")
# Out:
# <AxesSubplot:xlabel='price'>

# %%
plt.figure(figsize=(4,4))
plt.style.use("ggplot")

plt.scatter(x=range(10),
            y=y_test.head(10),
            color="r",
           label="Actual Points")
plt.scatter(x=range(10),
            y=y_pred_test[:10],
            color="g",
           label="Predicted Points")
plt.legend()
